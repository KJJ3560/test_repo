# %%
a = 5
a
# Out:
# 5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.email 'jjkim11@gmail.com'
# !git config --global user.name 'KJJ3560'

# %%
# !git add test_code.ipynb
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
cd /content/drive/MyDrive/Colab Notebooks/github/test_repo
# Out:
# /content/drive/MyDrive/Colab Notebooks/github/test_repo

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add test.ipynb
# !git commit -m "Connect Google Colab and Drive"
# Out:
# [main 102f2e9] Connect Google Colab and Drive
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 test.ipynb

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 289 bytes | 17.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/KJJ3560/test_repo.git
#    2dd9802..102f2e9  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %% [markdown]
# # test

# %%
a = 5
a
# Out:
# 5
